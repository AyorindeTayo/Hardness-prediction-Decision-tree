# %% [markdown]
# <a href="https://colab.research.google.com/github/AyorindeTayo/Hardness-prediction-Decision-tree/blob/main/Untitled66.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f9e4b25c-a221-48aa-acb9-0e07487a233c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f9e4b25c-a221-48aa-acb9-0e07487a233c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data_1004.xlsx to data_1004.xlsx
# ...

# %%
import pandas as pd

# %%
df=pd.read_excel('data_1004.xlsx')
df.head()
# Out:
#    S-temp  S-time  Wel-power  Wel-speed  Hardness
# 0    1000       5       1500          3     343.7
# 1    1000       5       1500          3     350.1
# 2    1000       5       1500          3     351.7
# 3    1000       5       1500          3     365.6
# 4    1000       5       1500          3     337.5

# %%
df.shape
# Out:
# (30, 5)

# %%
data=df

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   S-temp     30 non-null     int64
#  1   S-time     30 non-null     int64
#  2   Wel-power  30 non-null     int64
#  3   Wel-speed  30 non-null     int64
#  4   Hardness   30 non-null     float64
# dtypes: float64(1), int64(4)
# memory usage: 1.3 KB

# %%
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# To change scientific numbers to float
np.set_printoptions(formatter={'float_kind':'{:f}'.format})

# Increases the size of sns plots
sns.set(rc={'figure.figsize':(8,6)})

# Datetime lib
from pandas import to_datetime
import itertools
import warnings
import datetime
warnings.filterwarnings('ignore')

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, r2_score

# %%
# Your code goes here
X = data.drop('Hardness', axis=1).values# Input features (attributes)
y = data['Hardness'].values # Target vector
print('X shape: {}'.format(np.shape(X)))
print('y shape: {}'.format(np.shape(y)))

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.9, test_size=0.1, random_state=0)
# Out:
# X shape: (30, 4)
# y shape: (30,)

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor

# %%
regressor = DecisionTreeRegressor(random_state = 2022, max_depth=3)

# %%
regressor.fit(X, y)
# Out:
# DecisionTreeRegressor(max_depth=3, random_state=2022)

# %%
# !pip install -q dtreeviz
# Out:
#      |████████████████████████████████| 62 kB 1.1 MB/s
# ...

# %%
# !apt-get install graphviz
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# graphviz is already the newest version (2.40.1-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 62 not upgraded.

# %%
from dtreeviz.trees import *

# %%
import matplotlib.font_manager

# %%
from IPython.core.display import display, HTML
display(HTML(viz.svg()))
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" height="889.0" viewBox="0.0 0.0 456.0 889.0" width="456.0">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 885)">
# <title>G</title>
# <polygon fill="#ffffff" points="-4,4 -4,-885 452,-885 452,4 -4,4" stroke="transparent" />
# <text fill="#a020f0" font-family="Arial" font-size="14.00" text-anchor="middle" x="224" y="-865.8">Hardness Prediction</text>
#
# <g class="node" id="node1">
# <title>node1</title>
# <svg height="69px" preserveAspectRatio="xMinYMin meet" version="1.1" viewBox="0 0 173.17625 92.65225" width="130px" x="84.5" y="-580.5">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 92.65225  L 173.17625 92.65225  L 173.17625 -0  L 0 -0  z " style="fill:#ffffff;" />
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
# ...

# %%
data.columns
# Out:
# Index(['S-temp', 'S-time', 'Wel-power', 'Wel-speed', 'Hardness'], dtype='object')

# %%
viz = dtreeviz(regressor,
               X,
               y,
               target_name='Hardness',
               feature_names=['S-temp', 'S-time', 'Wel-power', 'Wel-speed'])
viz

# %%
import numpy as np

# %%
from sklearn import tree
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(10,5))
_ = tree.plot_tree(regressor,
                   feature_names = ['S-temp', 'S-time', 'Wel-power', 'Wel-speed'],
                   class_names = 'Hardness',
                   filled=True)
